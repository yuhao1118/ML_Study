# %%
import numpy as np
import scipy.io as sio
import matplotlib.pyplot as plt

# let's keep our keras backend tensorflow log quiet
import os
os.environ['TF_CPP_MIN_LOG_LEVEL']='3'

# keras imports for the dataset and building our neural network
from keras.models import Sequential, load_model
from keras.layers.core import Dense, Dropout, Activation
from keras.utils import np_utils
from keras.datasets import mnist
# Out:
# Using TensorFlow backend.

# %%
(X_train, y_train), (X_test, y_test) = mnist.load_data()

X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((60000, 28, 28), (60000,), (10000, 28, 28), (10000,))

# %%
# from sklearn.preprocessing import StandardScaler
# sc = StandardScaler()
# X = sc.fit_transform(X)
# y[y == 10] = 0

from sklearn.preprocessing import OneHotEncoder
oe = OneHotEncoder()

y = oe.fit_transform(y).toarray()
y.shape
# Out:
# (5000, 10)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((3750, 400), (1250, 400), (3750, 10), (1250, 10))

# %%
plt.figure(figsize=(8,8))
for index, (image, label) in enumerate(zip(X_train[:100], y_train[:100])):
    plt.subplot(10, 10, index + 1)
    plt.imshow(image.reshape(image_size,image_size).T, cmap=plt.cm.gray)
    plt.xticks(np.array([]))
    plt.yticks(np.array([]))

# %%
model = Sequential()
model.add(Dense(512, input_shape=(image_size ** 2,)))
model.add(Activation('relu'))                            
model.add(Dropout(0.2))

model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dropout(0.2))

model.add(Dense(10))
model.add(Activation('softmax'))

# %%
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

# %%
history = model.fit(X_train, y_train,
          batch_size=128, epochs=10,
          verbose=2,
          validation_data=(X_test, y_test))
# Out:
# Train on 3750 samples, validate on 1250 samples
# Epoch 1/10
#  - 0s - loss: 0.0057 - accuracy: 0.9981 - val_loss: 0.2903 - val_accuracy: 0.9504
# Epoch 2/10
#  - 0s - loss: 0.0037 - accuracy: 0.9987 - val_loss: 0.2941 - val_accuracy: 0.9568
# Epoch 3/10
#  - 0s - loss: 0.0059 - accuracy: 0.9989 - val_loss: 0.3555 - val_accuracy: 0.9496
# Epoch 4/10
#  - 0s - loss: 0.0076 - accuracy: 0.9973 - val_loss: 0.3346 - val_accuracy: 0.9536
# Epoch 5/10
#  - 0s - loss: 0.0041 - accuracy: 0.9989 - val_loss: 0.3122 - val_accuracy: 0.9528
# Epoch 6/10
#  - 0s - loss: 0.0029 - accuracy: 0.9992 - val_loss: 0.3126 - val_accuracy: 0.9536
# Epoch 7/10
#  - 0s - loss: 0.0030 - accuracy: 0.9995 - val_loss: 0.2932 - val_accuracy: 0.9568
# Epoch 8/10
#  - 0s - loss: 0.0020 - accuracy: 0.9989 - val_loss: 0.3074 - val_accuracy: 0.9520
# Epoch 9/10
#  - 0s - loss: 0.0048 - accuracy: 0.9979 - val_loss: 0.3120 - val_accuracy: 0.9512
# Epoch 10/10
#  - 0s - loss: 0.0054 - accuracy: 0.9987 - val_loss: 0.3662 - val_accuracy: 0.9536

# %%
# plotting the metrics
plt.subplot(2,1,1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='lower right')

plt.subplot(2,1,2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')

plt.tight_layout()

# %%
model.evaluate(X_test, y_test, verbose=2)
# Out:
# [0.36620495675988496, 0.9535999894142151]

# %%
y_pred = model.predict_classes(X_test)

plt.figure(figsize=(7,14))
for index, (image,) in enumerate(zip(X_test[:18])):
    plt.subplot(6, 3, index + 1)
    plt.imshow(image.reshape(image_size,image_size).T, cmap=plt.cm.gray)
    plt.title(
      "Predicted {}, Truth: {}".format(y_pred[index], 
                                       np.argmax(y_test[index])))
    plt.xticks(np.array([]))
    plt.yticks(np.array([]))
